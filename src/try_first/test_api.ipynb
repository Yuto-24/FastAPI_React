# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- ---------
# annotated-types           0.5.0
# anyio                     3.7.1
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.0
# async-lru                 2.0.4
# attrs                     23.1.0
# Babel                     2.13.0
# backcall                  0.2.0
# beautifulsoup4            4.12.2
# bleach                    6.0.0
# certifi                   2023.7.22
# cffi                      1.16.0
# chardet                   5.2.0
# charset-normalizer        3.3.0
# click                     8.1.7
# comm                      0.1.4
# contourpy                 1.1.1
# cycler                    0.12.0
# debugpy                   1.8.0
# decorator                 5.1.1
# defusedxml                0.7.1
# exceptiongroup            1.1.3
# executing                 2.0.0
# fastapi                   0.103.2
# fastjsonschema            2.18.1
# fastpip                   1.7.0
# fonttools                 4.43.0
# fqdn                      1.5.1
# h11                       0.14.0
# idna                      3.4
# ipykernel                 6.25.2
# ipython                   8.16.1
# ipython-genutils          0.2.0
# ipywidgets                8.1.1
# isoduration               20.11.0
# japanize-matplotlib       1.1.3
# jedi                      0.19.1
# Jinja2                    3.1.2
# json5                     0.9.14
# jsonpointer               2.4
# jsonschema                4.19.1
# jsonschema-specifications 2023.7.1
# jupyter                   1.0.0
# jupyter_client            8.3.1
# jupyter-console           6.6.3
# jupyter_core              5.3.2
# jupyter-events            0.7.0
# jupyter-lsp               2.2.0
# jupyter_server            2.7.3
# jupyter_server_terminals  0.4.4
# jupyterlab                4.0.6
# jupyterlab-pygments       0.2.2
# jupyterlab_server         2.25.0
# jupyterlab-widgets        3.0.9
# kiwisolver                1.4.5
# MarkupSafe                2.1.3
# matplotlib                3.7.1
# matplotlib-inline         0.1.6
# mistune                   3.0.2
# nbclient                  0.8.0
# nbconvert                 7.9.0
# nbformat                  5.9.2
# nest-asyncio              1.5.8
# notebook                  7.0.4
# notebook_shim             0.2.3
# numpy                     1.26.0
# overrides                 7.4.0
# packaging                 23.2
# pandocfilters             1.5.0
# parso                     0.8.3
# pexpect                   4.8.0
# pickleshare               0.7.5
# Pillow                    10.0.1
# pip                       23.2.1
# platformdirs              3.11.0
# prometheus-client         0.17.1
# prompt-toolkit            3.0.39
# psutil                    5.9.5
# ptyprocess                0.7.0
# pure-eval                 0.2.2
# pycparser                 2.21
# pydantic                  2.4.2
# pydantic_core             2.10.1
# Pygments                  2.16.1
# pyparsing                 3.1.1
# python-dateutil           2.8.2
# python-json-logger        2.0.7
# PyYAML                    6.0.1
# pyzmq                     25.1.1
# qtconsole                 5.4.4
# QtPy                      2.4.0
# referencing               0.30.2
# regex                     2023.10.3
# requests                  2.31.0
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rpds-py                   0.10.3
# Send2Trash                1.8.2
# setuptools                65.5.0
# six                       1.16.0
# sniffio                   1.3.0
# soupsieve                 2.5
# stack-data                0.6.3
# starlette                 0.27.0
# terminado                 0.17.1
# tinycss2                  1.2.1
# tomli                     2.0.1
# tornado                   6.3.3
# traitlets                 5.11.2
# types-python-dateutil     2.8.19.14
# typing_extensions         4.8.0
# uri-template              1.3.0
# urllib3                   2.0.6
# uvicorn                   0.23.2
# wcwidth                   0.2.8
# webcolors                 1.13
# webencodings              0.5.1
# websocket-client          1.6.3
# wheel                     0.41.2
# widgetsnbextension        4.0.9

# %%
import requests
from pprint import pprint
from typing import Optional, List
from pydantic import BaseModel

class ShopInfo(BaseModel):
    name: str
    location: str

class Item(BaseModel):
    name: str
    description: Optional[str] = None
    price: int
    tax: Optional[float] = None

class Data(BaseModel):
    shop_info:Optional[ShopInfo] = None
    items: List[Item]

# %%
def main():
    server = "http://localhost"
    port = "8000"
    dir = "item"

    body: Item = {
        "name": "apple",
        "description": "This is an apple",
        "price": 128,
        "tax": 1.08,
    }

    url = server + ":" + port + "/" + dir
    print(
        url
        + "?"
        + "name="
        + body["name"]
        + "&description"
        + body["description"].replace(" ", "+")
        + "&price="
        + str(body["price"])
        + "&tax="
        + str(body["tax"])
    )

    res = requests.post(url, json=body)
    pprint(res.json())

    # # other dir
    # dir = "studies"
    # url = server + ":" + port + "/" + dir
    # print(url)

    # res = requests.get(url)
    # pprint(res.json())


if __name__ == "__main__":
    main()
# Out:
# http://localhost:8000/item?name=apple&descriptionThis+is+an+apple&price=128&tax=1.08
# {'message': 'appleは139円です。', '詳細': 'This is an apple'}
